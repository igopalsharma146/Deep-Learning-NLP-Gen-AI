# %%
import os 
import pandas as  pd
import pathlib
import cv2
from PIL import Image
import numpy as np 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\jaikr\\OneDrive\\Desktop\\1 MT 6TH\\deep learning\\CNN'

# %%
os.path.join(current_dir,"Data")
# Out:
# 'c:\\Users\\jaikr\\OneDrive\\Desktop\\1 MT 6TH\\deep learning\\CNN\\Data'

# %%
print("total no of cat images : ",len(os.listdir(os.path.join(current_dir,"Data","images","cats"))))
# Out:
# total no of cat images :  349

# %%
print("total no of dogs images : ",len(os.listdir(os.path.join(current_dir,"Data","images","dogs"))))
# Out:
# total no of dogs images :  348

# %%
image_path = os.path.join(current_dir,"Data","images")
image_path
# Out:
# 'c:\\Users\\jaikr\\OneDrive\\Desktop\\1 MT 6TH\\deep learning\\CNN\\Data\\images'

# %%
os.listdir(image_path)
# Out:
# ['cats', 'dogs']

# %%
path_dict = {"cats":[],"dogs":[]}
for dir in os.listdir(image_path):
    directory_path = os.path.join(image_path,dir)
    for images in os.listdir(directory_path):
        path_dict[dir].append(os.path.join(directory_path,images))

# %%
cat_image_demo = Image.open(path_dict["cats"][1])
cat_image_demo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2000x1333>
